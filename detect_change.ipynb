# %%
import ee
service_account = 'clgx-gis-app-dev-06e3@appspot.gserviceaccount.com'
credentials = ee.ServiceAccountCredentials(service_account, 'clgx-gis-app-dev-06e3-a1a85a16331a.json')
ee.Initialize(credentials)

# %%
import geopandas as gpd
import geojson
from shapely import wkt
from datetime import datetime

# %%
startDate = '2020-06-01'
endDate = '2020-06-16'

# %%
bbox = gpd.read_file('boulder_bounds.shp')

# %%
bbox
# Out:
#    NoteType  Name Notes created_us  created_da last_edite  last_edi_1  \
# 0         0  None  None   ABREUNIG  2023-10-17   ABREUNIG  2023-10-17
#
#    Shape_Leng  Shape_Area                                           geometry
# 0    0.207454     0.00243  POLYGON Z ((-105.23135 40.05088 0.00000, -105....

# %%
coords = list(bbox['geometry'][0].exterior.coords)

# drop z values
coords = [list(c[:2]) for c in coords]
coords
# Out:
# [[-105.23134908199995, 40.05088386700004],
#  [-105.16393977399997, 40.05000842100003],
#  [-105.16327276799996, 40.014573720000044],
#  [-105.23180764799997, 40.01482384700006],
#  [-105.23134908199995, 40.05088386700004]]

# %%
aoi = ee.Geometry.Polygon(coords)

# %%
s1 = ee.ImageCollection('COPERNICUS/S1_GRD')
images = (s1.filterDate(startDate, endDate).
            filterMetadata('instrumentMode', 'equals', 'IW').
            filterMetadata('orbitProperties_pass', 'equals', 'DESCENDING').
            filterBounds(aoi).
            filter(ee.Filter.eq('resolution_meters', 10))
)
lst = images.toList(images.size())    
i1 = ee.Image(lst.get(0))
i2 = ee.Image(lst.get(1))
i3 = ee.Image(lst.get(2))

i1_props = i1.getInfo()['properties']
i2_props = i2.getInfo()['properties']
i3_props = i3.getInfo()['properties']

# %%
images_meta_list
# Out:
# [{'type': 'Image',
#   'bands': [{'id': 'VV',
#     'data_type': {'type': 'PixelType', 'precision': 'double'},
#     'dimensions': [29008, 21488],
#     'crs': 'EPSG:32613',
#     'crs_transform': [10, 0, 245470.38943568667, 0, -10, 4498062.075024601]},
#    {'id': 'VH',
#     'data_type': {'type': 'PixelType', 'precision': 'double'},
#     'dimensions': [29008, 21488],
#     'crs': 'EPSG:32613',
#     'crs_transform': [10, 0, 245470.38943568667, 0, -10, 4498062.075024601]},
#    {'id': 'angle',
#     'data_type': {'type': 'PixelType', 'precision': 'float'},
#     'dimensions': [21, 10],
#     'crs': 'EPSG:32613',
#     'crs_transform': [-12777.510236766713,
#      -3931.9315816158196,
#      534809.5794988564,
#      2393.948875727132,
#      -20007.636559526436,
#      4449483.408209413]}],
#   'version': 1698265761925472,
#   'id': 'COPERNICUS/S1_GRD/S1A_IW_GRDH_1SDV_20200603T130946_20200603T131011_032853_03CE2C_9FA0',
#   'properties': {'SNAP_Graph_Processing_Framework_GPF_vers': '7.0.3',
#    'SLC_Processing_facility_org': 'ESA',
#    'SLC_Processing_facility_country': 'Germany',
#    'GRD_Post_Processing_facility_org': 'ESA',
#    'transmitterReceiverPolarisation': ['VV', 'VH'],
#    'GRD_Post_Processing_start': 1591197475160,
#    'sliceNumber': 5,
#    'GRD_Post_Processing_facility_name': 'Copernicus S1 Core Ground Segment - DPA',
#    'resolution': 'H',
#    'SLC_Processing_facility_name': 'Copernicus S1 Core Ground Segment - DPA',
#    'system:footprint': {'type': 'LinearRing',
#     'coordinates': [[-104.6331970634189, 40.20150376792165],
#      [-104.78570569097673, 40.22382309284098],
#      [-106.16415496007475, 40.41573419479688],
#      [-107.55268381481329, 40.59136517703773],
#      [-107.55395638486213, 40.586524479115255],
#      [-107.66602256381753, 40.08595444936492],
#      [-107.74186411342781, 39.73029924088559],
#      [-107.81703085462321, 39.3746022559311],
#      [-107.87085196546532, 39.1136201161025],
#      [-107.87363323591129, 39.09701162983611],
#      [-107.87224503802945, 39.09084073239042],
#      [-106.4186385757969, 38.90115978496137],
#      [-105.03287313736634, 38.70249579340447],
#      [-105.02657188228441, 38.72337114276125],
#      [-104.97404723960302, 38.90829150380514],
#      [-104.8526877843297, 39.36506700351885],
#      [-104.79795163110441, 39.5707780185691],
#      [-104.71722554621809, 39.87867864677697],
#      [-104.66707117809369, 40.06990433587574],
#      [-104.6331970634189, 40.20150376792165]]},
#    'familyName': 'SENTINEL-1',
#    'segmentStartTime': 1591189682585,
#    'missionDataTakeID': 249388,
#    'GRD_Post_Processing_facility_country': 'Germany',
#    'nssdcIdentifier': '2014-016A',
#    'productClass': 'S',
#    'phaseIdentifier': 1,
#    'orbitProperties_pass': 'DESCENDING',
#    'relativeOrbitNumber_stop': 56,
#    'system:time_end': 1591189786000,
#    'SLC_Processing_facility_site': 'DLR-Oberpfaffenhofen',
#    'GRD_Post_Processing_stop': 1591198141000,
#    'system:time_start': 1591189786000,
#    'instrumentMode': 'IW',
#    'totalSlices': 18,
#    'SLC_Processing_stop': 1591197912000,
#    'startTimeANX': 2303505,
#    'SLC_Processing_start': 1591197586000,
#    'resolution_meters': 10,
#    'instrumentSwath': 'IW',
#    'relativeOrbitNumber_start': 56,
#    'productTimelinessCategory': 'Fast-24h',
#    'SLC_Processing_software_name': 'Sentinel-1 IPF',
#    'sliceProductFlag': 'true',
#    'S1TBX_Calibration_vers': '7.0.2',
#    'orbitNumber_start': 32853,
#    'GRD_Post_Processing_facility_site': 'DLR-Oberpfaffenhofen',
#    'instrument': 'Synthetic Aperture Radar',
#    'GRD_Post_Processing_software_name': 'Sentinel-1 IPF',
#    'platform_number': 'A',
#    'S1TBX_SAR_Processing_vers': '7.0.2',
#    'productType': 'GRD',
#    'orbitProperties_ascendingNodeTime': 1591187482781,
#    'stopTimeANX': 2328504,
#    'productComposition': 'Slice',
#    'productClassDescription': 'SAR Standard L1 Product',
#    'GRD_Post_Processing_software_version': '003.20',
#    'SLC_Processing_software_version': '003.20',
#    'orbitNumber_stop': 32853,
#    'instrumentConfigurationID': 6,
#    'system:asset_size': 4055404027,
#    'cycleNumber': 202,
#    'system:index': 'S1A_IW_GRDH_1SDV_20200603T130946_20200603T131011_032853_03CE2C_9FA0'}},
#  {'type': 'Image',
#   'bands': [{'id': 'VV',
#     'data_type': {'type': 'PixelType', 'precision': 'double'},
#     'dimensions': [28895, 21409],
#     'crs': 'EPSG:32613',
#     'crs_transform': [10, 0, 418349.4801373321, 0, -10, 4453388.631801897]},
#    {'id': 'VH',
#     'data_type': {'type': 'PixelType', 'precision': 'double'},
#     'dimensions': [28895, 21409],
#     'crs': 'EPSG:32613',
#     'crs_transform': [10, 0, 418349.4801373321, 0, -10, 4453388.631801897]},
#    {'id': 'angle',
#     'data_type': {'type': 'PixelType', 'precision': 'float'},
#     'dimensions': [21, 10],
#     'crs': 'EPSG:32613',
#     'crs_transform': [-12835.182880366337,
#      -3415.4832417328143,
#      702965.8912818228,
#      2114.1203956035897,
#      -20111.10113143362,
#      4408665.726729645]}],
#   'version': 1698265761925472,
#   'id': 'COPERNICUS/S1_GRD/S1A_IW_GRDH_1SDV_20200610T130139_20200610T130204_032955_03D135_658B',
#   'properties': {'SNAP_Graph_Processing_Framework_GPF_vers': '7.0.3',
#    'SLC_Processing_facility_org': 'ESA',
#    'SLC_Processing_facility_country': 'Germany',
#    'GRD_Post_Processing_facility_org': 'ESA',
#    'transmitterReceiverPolarisation': ['VV', 'VH'],
#    'GRD_Post_Processing_start': 1591801656466,
#    'sliceNumber': 5,
#    'GRD_Post_Processing_facility_name': 'Copernicus S1 Core Ground Segment - DPA',
#    'resolution': 'H',
#    'SLC_Processing_facility_name': 'Copernicus S1 Core Ground Segment - DPA',
#    'system:footprint': {'type': 'LinearRing',
#     'coordinates': [[-105.59719187200008, 40.169413475854235],
#      [-105.60167557648995, 40.158304626004835],
#      [-105.61840333953123, 40.09928793176529],
#      [-105.63489614653398, 40.01810940487833],
#      [-105.75844841258534, 39.393506153174656],
#      [-105.87990328102302, 38.76872791514813],
#      [-105.89177304558203, 38.69973997555613],
#      [-105.58091538037735, 38.660461405359364],
#      [-105.1432388970435, 38.603689350660474],
#      [-103.04260882036738, 38.307115488680964],
#      [-103.00529956840992, 38.45519975689783],
#      [-102.95673929892827, 38.65277980428391],
#      [-102.93250727202728, 38.752100532308724],
#      [-102.8153033992805, 39.23096632603192],
#      [-102.67113152528361, 39.81023504976722],
#      [-102.692975300276, 39.8134934259767],
#      [-103.58171204888511, 39.94099522507842],
#      [-105.25598087775532, 40.16154225539708],
#      [-105.58206721471231, 40.20151039292451],
#      [-105.58755067475941, 40.192672236638636],
#      [-105.59719187200008, 40.169413475854235]]},
#    'familyName': 'SENTINEL-1',
#    'segmentStartTime': 1591793995955,
#    'missionDataTakeID': 250165,
#    'GRD_Post_Processing_facility_country': 'Germany',
#    'nssdcIdentifier': '2014-016A',
#    'productClass': 'S',
#    'phaseIdentifier': 1,
#    'orbitProperties_pass': 'DESCENDING',
#    'relativeOrbitNumber_stop': 158,
#    'system:time_end': 1591794099000,
#    'SLC_Processing_facility_site': 'DLR-Oberpfaffenhofen',
#    'GRD_Post_Processing_stop': 1591802321000,
#    'system:time_start': 1591794099000,
#    'instrumentMode': 'IW',
#    'totalSlices': 18,
#    'SLC_Processing_stop': 1591802094000,
#    'startTimeANX': 2310004,
#    'SLC_Processing_start': 1591801772000,
#    'resolution_meters': 10,
#    'instrumentSwath': 'IW',
#    'relativeOrbitNumber_start': 158,
#    'productTimelinessCategory': 'Fast-24h',
#    'SLC_Processing_software_name': 'Sentinel-1 IPF',
#    'sliceProductFlag': 'true',
#    'S1TBX_Calibration_vers': '7.0.2',
#    'orbitNumber_start': 32955,
#    'GRD_Post_Processing_facility_site': 'DLR-Oberpfaffenhofen',
#    'instrument': 'Synthetic Aperture Radar',
#    'GRD_Post_Processing_software_name': 'Sentinel-1 IPF',
#    'platform_number': 'A',
#    'S1TBX_SAR_Processing_vers': '7.0.2',
#    'productType': 'GRD',
#    'orbitProperties_ascendingNodeTime': 1591791789651,
#    'stopTimeANX': 2335002,
#    'productComposition': 'Slice',
#    'productClassDescription': 'SAR Standard L1 Product',
#    'GRD_Post_Processing_software_version': '003.20',
#    'SLC_Processing_software_version': '003.20',
#    'orbitNumber_stop': 32955,
#    'instrumentConfigurationID': 6,
#    'system:asset_size': 4060241223,
#    'cycleNumber': 202,
#    'system:index': 'S1A_IW_GRDH_1SDV_20200610T130139_20200610T130204_032955_03D135_658B'}},
#  {'type': 'Image',
#   'bands': [{'id': 'VV',
#     'data_type': {'type': 'PixelType', 'precision': 'double'},
#     'dimensions': [29009, 21489],
#     'crs': 'EPSG:32613',
#     'crs_transform': [10, 0, 245419.83975836978, 0, -10, 4498062.859532573]},
#    {'id': 'VH',
#     'data_type': {'type': 'PixelType', 'precision': 'double'},
#     'dimensions': [29009, 21489],
#     'crs': 'EPSG:32613',
#     'crs_transform': [10, 0, 245419.83975836978, 0, -10, 4498062.859532573]},
#    {'id': 'angle',
#     'data_type': {'type': 'PixelType', 'precision': 'float'},
#     'dimensions': [21, 10],
#     'crs': 'EPSG:32613',
#     'crs_transform': [-12777.42125934601,
#      -3932.2079004995758,
#      534770.7892526708,
#      2394.1256946744397,
#      -20007.50531285908,
#      4449478.234756933]}],
#   'version': 1698265761925472,
#   'id': 'COPERNICUS/S1_GRD/S1A_IW_GRDH_1SDV_20200615T130947_20200615T131012_033028_03D365_A56F',
#   'properties': {'SNAP_Graph_Processing_Framework_GPF_vers': '7.0.3',
#    'SLC_Processing_facility_org': 'ESA',
#    'SLC_Processing_facility_country': 'Germany',
#    'GRD_Post_Processing_facility_org': 'ESA',
#    'transmitterReceiverPolarisation': ['VV', 'VH'],
#    'GRD_Post_Processing_start': 1592234147045,
#    'sliceNumber': 5,
#    'GRD_Post_Processing_facility_name': 'Copernicus S1 Core Ground Segment - DPA',
#    'resolution': 'H',
#    'SLC_Processing_facility_name': 'Copernicus S1 Core Ground Segment - DPA',
#    'system:footprint': {'type': 'LinearRing',
#     'coordinates': [[-105.92736846159295, 38.83263856594208],
#      [-105.03321128477977, 38.70243623608723],
#      [-105.02680836218414, 38.72364858798198],
#      [-104.97428390990696, 38.90910964862794],
#      [-104.85292463038877, 39.36588527723925],
#      [-104.79623552999263, 39.57881103608832],
#      [-104.71746138555875, 39.87976751502072],
#      [-104.66778051253999, 40.068842195150864],
#      [-104.63363468390178, 40.201455993330704],
#      [-104.82789226874556, 40.22984682901365],
#      [-106.1856614350105, 40.418495612751826],
#      [-107.55329490772169, 40.59136081493782],
#      [-107.55424044311467, 40.58760578462278],
#      [-107.66628469896808, 40.086496006773594],
#      [-107.74230016077503, 39.73083656107263],
#      [-107.81763909674883, 39.375135127227495],
#      [-107.8708648918753, 39.11612542687558],
#      [-107.87418555194417, 39.09686288303823],
#      [-107.8728298032641, 39.09083658387742],
#      [-106.52199012635039, 38.91517946508147],
#      [-105.92736846159295, 38.83263856594208]]},
#    'familyName': 'SENTINEL-1',
#    'segmentStartTime': 1592226483465,
#    'missionDataTakeID': 250725,
#    'GRD_Post_Processing_facility_country': 'Germany',
#    'nssdcIdentifier': '2014-016A',
#    'productClass': 'S',
#    'phaseIdentifier': 1,
#    'orbitProperties_pass': 'DESCENDING',
#    'relativeOrbitNumber_stop': 56,
#    'system:time_end': 1592226587000,
#    'SLC_Processing_facility_site': 'DLR-Oberpfaffenhofen',
#    'GRD_Post_Processing_stop': 1592234813000,
#    'system:time_start': 1592226587000,
#    'instrumentMode': 'IW',
#    'totalSlices': 18,
#    'SLC_Processing_stop': 1592234585000,
#    'startTimeANX': 2303504,
#    'SLC_Processing_start': 1592234258000,
#    'resolution_meters': 10,
#    'instrumentSwath': 'IW',
#    'relativeOrbitNumber_start': 56,
#    'productTimelinessCategory': 'Fast-24h',
#    'SLC_Processing_software_name': 'Sentinel-1 IPF',
#    'sliceProductFlag': 'true',
#    'S1TBX_Calibration_vers': '7.0.2',
#    'orbitNumber_start': 33028,
#    'GRD_Post_Processing_facility_site': 'DLR-Oberpfaffenhofen',
#    'instrument': 'Synthetic Aperture Radar',
#    'GRD_Post_Processing_software_name': 'Sentinel-1 IPF',
#    'platform_number': 'A',
#    'S1TBX_SAR_Processing_vers': '7.0.2',
#    'productType': 'GRD',
#    'orbitProperties_ascendingNodeTime': 1592224283662,
#    'stopTimeANX': 2328503,
#    'productComposition': 'Slice',
#    'productClassDescription': 'SAR Standard L1 Product',
#    'GRD_Post_Processing_software_version': '003.20',
#    'SLC_Processing_software_version': '003.20',
#    'orbitNumber_stop': 33028,
#    'instrumentConfigurationID': 6,
#    'system:asset_size': 4053944730,
#    'cycleNumber': 203,
#    'system:index': 'S1A_IW_GRDH_1SDV_20200615T130947_20200615T131012_033028_03D365_A56F'}}]

# %%
images_meta_list = images.toList(count=20).getInfo()

# %%
def get_dates(image):
    return ee.Feature(None, {'aq_date': ee.Date(image.get('system:time_start')).format('YYYY-MM-dd')})

# %%
dates = images.map(get_dates)

# %%
feat_list = dates.getInfo()['features']

# %%
aq_dates = [(d['id'], d['properties']['aq_date']) for d in feat_list]
aq_dates = sorted(aq_dates, key=lambda x: datetime.strptime(x[1], '%Y-%m-%d'))

# %%
aq_dates
# Out:
# [('S1A_IW_GRDH_1SDV_20200603T130946_20200603T131011_032853_03CE2C_9FA0',
#   '2020-06-03'),
#  ('S1A_IW_GRDH_1SDV_20200610T130139_20200610T130204_032955_03D135_658B',
#   '2020-06-10'),
#  ('S1A_IW_GRDH_1SDV_20200615T130947_20200615T131012_033028_03D365_A56F',
#   '2020-06-15')]

# %% [markdown]
# ## begin to detect change

# %%
import folium
from folium import plugins

# %%
# create a feature collection from i1, i2, i3
fc = ee.ImageCollection([i1, i2, i3])

# reproject to 32614
fc = fc.map(lambda img: img.reproject(crs='EPSG:32614', scale=10))

# %%
def specle_filterVV(img):
    vv = img.select('VV')
    vv_smoothed = vv.focal_median(50,'circle','meters').rename('VV_Filtered')
    return img.addBands(vv_smoothed)

def specle_filterVH(img):
    vh = img.select('VH')
    vh_smoothed = vh.focal_median(50,'circle','meters').rename('VH_Filtered')
    return img.addBands(vh_smoothed)

def dpsvi(img):
    dpsvi = ((img.select('VV_Filtered').add(img.select('VH_Filtered'))).divide(img.select('VV_Filtered'))).rename('DPSVI')
    return img.addBands(dpsvi)

# %%
def clip_img(self):
    """Clips a list of images."""
    return ee.Image(self).clip(aoi)

# %%
filterd_ic = fc.map(specle_filterVV)
filterd_ic = filterd_ic.map(specle_filterVH)

# %%
im_list = filterd_ic.toList(filterd_ic.size())
im_list_clipped = im_list.map(clip_img)

# %%
img1_vv = ee.Image(im_list_clipped.get(0)).select('VV_Filtered')
img1_vh = ee.Image(im_list_clipped.get(0)).select('VH_Filtered')
img2_vv = ee.Image(im_list_clipped.get(1)).select('VV_Filtered')
img2_vh = ee.Image(im_list_clipped.get(1)).select('VH_Filtered')

diff_vv = img1_vv.subtract(img2_vv).abs().rename('VV_diff')
diff_vh = img1_vh.subtract(img2_vh).abs().rename('VH_diff')

# %%
diff_vv_id_dict = diff_vv.getMapId()
diff_vh_id_dict = diff_vh.getMapId()

# %%
# create map object
map = folium.Map(location=[40.0150, -105.2705], zoom_start=12)

basemaps = {
    'Google Maps': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=m&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Maps',
        overlay = True,
        control = True
    ),
    'Google Satellite': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=s&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Satellite',
        overlay = True,
        control = True
    ),
    'Google Terrain': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=p&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Terrain',
        overlay = True,
        control = True
    ),
    'Google Satellite Hybrid': folium.TileLayer(
        tiles = 'https://mt1.google.com/vt/lyrs=y&x={x}&y={y}&z={z}',
        attr = 'Google',
        name = 'Google Satellite',
        overlay = True,
        control = True
    ),
    'Esri Satellite': folium.TileLayer(
        tiles = 'https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}',
        attr = 'Esri',
        name = 'Esri Satellite',
        overlay = True,
        control = True
    )
}

# %%
basemaps['Google Satellite Hybrid'].add_to(map)


diff_vv_folium = folium.raster_layers.TileLayer(
            tiles = diff_vv_id_dict['tile_fetcher'].url_format,
            attr = 'Google Earth Engine',
            name = 'diff_vv',
            overlay = True,
            control = True
            ).add_to(map)

diff_vh_folium = folium.raster_layers.TileLayer(
            tiles = diff_vh_id_dict['tile_fetcher'].url_format,
            attr = 'Google Earth Engine',
            name = 'diff_vh',
            overlay = True,
            control = True
            ).add_to(map)

# %%
map.add_child(folium.LayerControl())
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cce2f5ef18fb91578ba983037bb06d29 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cce2f5ef18fb91578ba983037bb06d29&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cce2f5ef18fb91578ba983037bb06d29 = L.map(
#                 &quot;map_cce2f5ef18fb91578ba983037bb06d29&quot;,
#                 {
#                     center: [40.015, -105.2705],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f444e6e30900019128ce324eace89e37 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cce2f5ef18fb91578ba983037bb06d29);
#
#
#             var tile_layer_49ab7c0ec24bdc580d52ab5a70cfed41 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=y\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cce2f5ef18fb91578ba983037bb06d29);
#
#
#             var tile_layer_eacb4b46d67594816d24fdc2d64ed31c = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps/211d3380e063a3f526bc2cfa2435eed4-de511f67077101d00979b7597df0ee05/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cce2f5ef18fb91578ba983037bb06d29);
#
#
#             var tile_layer_f7052945c09b25e8c88fee8080bab12e = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/earthengine-legacy/maps/7fc53a7f9ff013682276d32f7cbb8205-09cf66ec25bdfcb476d5ca2a0262eea2/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_cce2f5ef18fb91578ba983037bb06d29);
#
#
#             var layer_control_1c1b2d34b7b32bca71ac07fa0902b457 = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_f444e6e30900019128ce324eace89e37,
#                 },
#                 overlays :  {
#                     &quot;Google Satellite&quot; : tile_layer_49ab7c0ec24bdc580d52ab5a70cfed41,
#                     &quot;diff_vv&quot; : tile_layer_eacb4b46d67594816d24fdc2d64ed31c,
#                     &quot;diff_vh&quot; : tile_layer_f7052945c09b25e8c88fee8080bab12e,
#                 },
#             };
#             L.control.layers(
#                 layer_control_1c1b2d34b7b32bca71ac07fa0902b457.base_layers,
#                 layer_control_1c1b2d34b7b32bca71ac07fa0902b457.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_cce2f5ef18fb91578ba983037bb06d29);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
